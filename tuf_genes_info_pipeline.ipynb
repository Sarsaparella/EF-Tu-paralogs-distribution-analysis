# %%
import pandas as pd
from ete3 import NCBITaxa
ncbi = NCBITaxa()

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Download list of completed genomes from [Prokaryotic RefSeq Genomes dataset](https://www.ncbi.nlm.nih.gov/datasets/genome/?taxon=2,2157&reference_only=true&assembly_level=3:3)
#
# Extract column with genome accessions and feed this list of acessions to this basic script that uses [ncbi-datasets-cli software](https://www.ncbi.nlm.nih.gov/datasets/docs/v2/command-line-tools/download-and-install/) to download genomes

# %%
# !./download_genomes.sh < test_genomes.txt 2>/dev/null
# Out:
# GCA_030445085.2
# GCF_000005845.2
# GCF_000006685.1
# GCF_000006765.1
# GCF_000006925.2
# GCF_000006945.2
# GCF_000006985.1
# GCF_000007025.1
# GCF_000007085.1
# GCF_000007125.1

# %% [markdown]
# Unpack downloaded genomes

# %%
# !wc -l test_genomes.txt
# Out:
# 10 test_genomes.txt

# %%
# !ls Unpacked_genomes/ | wc -l
# Out:
# 10

# %% [markdown]
# ## Extracting the list of EF-Tu genes

# %% [markdown]
# Run this simple script to extract info about tuf genes from downloaded genomes, this script will create tuf_extr.tsv table

# %%
# !./extract_tufs.sh < test_genomes.txt 2>/dev/null

# %% [markdown]
# ## Filter out list of genes and assign taxonomy for each assembly

# %%
eftu = pd.read_csv('tuf_extr.tsv', sep='\t')
eftu
# Out:
#    Assemly_accession Refseq_accession    start      end strand        gene_id  \
# 0    GCA_030445085.2       CP124113.1   494670   495851      +    QIA01_02370
# 1    GCF_000005845.2      NC_000913.3   177665   178462      -          b0158
# 2    GCF_000005845.2      NC_000913.3  3470148  3471329      -          b3339
# 3    GCF_000005845.2      NC_000913.3  4175944  4177125      +          b3980
# 4    GCF_000006685.1      NC_002620.2   712354   713535      -     TC_RS03020
# 5    GCF_000006765.1      NC_002516.2  3244345  3246327      +         PA2891
# 6    GCF_000006765.1      NC_002516.2  4767814  4769004      -         PA4265
# 7    GCF_000006765.1      NC_002516.2  4784319  4785509      -         PA4277
# 8    GCF_000006925.2      NC_004337.2   169320   170117      -         SF0150
# 9    GCF_000006925.2      NC_004337.2  3439425  3440606      -         SF3357
# 10   GCF_000006925.2      NC_004337.2  4195696  4196877      +         SF4053
# 11   GCF_000006945.2      NC_003197.2   241273   242070      -        STM0206
# 12   GCF_000006945.2      NC_003197.2  3598312  3599493      -        STM3445
# 13   GCF_000006945.2      NC_003197.2  4360616  4361797      +        STM4146
# 14   GCF_000006985.1      NC_002932.3  2064827  2066005      -  AYT24_RS09945
# 15   GCF_000007025.1      NC_003103.1   934454   935635      -     RC_RS05040
# 16   GCF_000007085.1      NC_003869.1  2176300  2177499      -    TTE_RS10955
# 17   GCF_000007085.1      NC_003869.1  2191779  2192978      -    TTE_RS11025
# 18   GCF_000007125.1      NC_003317.1   768090   769262      +    BME_RS03700
# 19   GCF_000007125.1      NC_003317.1   786042   787214      +    BME_RS03770
#
#    gene_name      protein_id      locus_tag  \
# 0        tuf      WKD00810.1    QIA01_02370
# 1       btuF     NP_414700.1          b0158
# 2       tufA     NP_417798.1          b3339
# 3       tufB     NP_418407.1          b3980
# 4        tuf  WP_010904371.1     TC_RS03020
# 5       atuF     NP_251581.1         PA2891
# 6       tufA     NP_252955.1         PA4265
# 7       tufB     NP_252967.1         PA4277
# 8       yadT     NP_706106.1         SF0150
# 9        tuf     NP_709113.2         SF3357
# 10       tuf     NP_709775.1         SF4053
# 11      btuF     NP_459211.1        STM0206
# 12      tufA     NP_462349.1        STM3445
# 13      tufB     NP_463015.1        STM4146
# 14       tuf  WP_010933844.1  AYT24_RS09945
# 15       tuf  WP_010977589.1     RC_RS05040
# 16       tuf  WP_011026340.1    TTE_RS10955
# 17       tuf  WP_011026354.1    TTE_RS11025
# 18       tuf  WP_002970090.1    BME_RS03700
# 19       tuf  WP_002970090.1    BME_RS03770
#
#                                               product pseudo partial
# 0                                elongation factor Tu     --      --
# 1   vitamin B12 ABC transporter periplasmic bindin...     --      --
# 2                  translation elongation factor Tu 1     --      --
# 3                  translation elongation factor Tu 2     --      --
# 4                                elongation factor Tu     --      --
# 5               geranyl-CoA carboxylase subunit alpha     --      --
# 6                                elongation factor Tu     --      --
# 7                                elongation factor Tu     --      --
# 8                vitamin B12-transporter protein BtuF     --      --
# 9                                elongation factor Tu     --      --
# 10                               elongation factor Tu     --      --
# 11     putative cobalamin periplasmic binding protein     --      --
# 12              protein chain elongation factor EF-Tu     --      --
# 13              protein chain elongation factor EF-Tu     --      --
# 14                               elongation factor Tu     --      --
# 15                               elongation factor Tu     --      --
# 16                               elongation factor Tu     --      --
# 17                               elongation factor Tu     --      --
# 18                               elongation factor Tu     --      --
# 19                               elongation factor Tu     --      --

# %% [markdown]
# Download taxonomy for each assembly accession using NCBITaxa package

# %%
taxons = pd.read_csv('ncbi_complete_bacteria_genomes_list.tsv', sep='\t')
taxons = taxons[['Assembly Accession', 'Organism Taxonomic ID', 'Organism Name']]

def get_phylum(taxid):
    try:
        lineage = ncbi.get_lineage(taxid)
        names = ncbi.get_taxid_translator(lineage)
        ranks = ncbi.get_rank(lineage)
        phylum = [names[t] for t in lineage if ranks[t] == 'phylum']
        return phylum[0] if phylum else None
    except:
        return None

def get_class(taxid):
    try:
        lineage = ncbi.get_lineage(taxid)
        names = ncbi.get_taxid_translator(lineage)
        ranks = ncbi.get_rank(lineage)
        classes = [names[t] for t in lineage if ranks[t] == 'class']
        return classes[0] if classes else None
    except:
        return None

taxons["Phylum"] = taxons["Organism Taxonomic ID"].apply(get_phylum)
taxons["Class"] = taxons["Organism Taxonomic ID"].apply(get_class)

taxons.to_csv("genomes_with_phylum.tsv", sep='\t', index=False)

# %%
taxons
# Out:
#      Assembly Accession  Organism Taxonomic ID  \
# 0       GCF_000006945.2                  99287
# 1       GCF_000195955.2                  83332
# 2       GCF_000009045.1                 224308
# 3       GCF_009035845.1                    470
# 4       GCF_000015785.2                 326423
# ...                 ...                    ...
# 6354    GCF_000497445.1                1352936
# 6355    GCF_900258455.1                 164393
# 6356    GCF_037672085.1                 650003
# 6357    GCF_000154965.1                 463191
# 6358    GCF_001439985.1                 125593
#
#                                           Organism Name          Phylum  \
# 0     Salmonella enterica subsp. enterica serovar Ty...  Pseudomonadota
# 1                      Mycobacterium tuberculosis H37Rv  Actinomycetota
# 2            Bacillus subtilis subsp. subtilis str. 168       Bacillota
# 3                               Acinetobacter baumannii  Pseudomonadota
# 4                             Bacillus velezensis FZB42       Bacillota
# ...                                                 ...             ...
# 6354  Streptomyces roseochromogenus subsp. oscitans ...  Actinomycetota
# 6355                       Latilactobacillus fuchuensis       Bacillota
# 6356                                Vibrio paracholerae  Pseudomonadota
# 6357                    Streptomyces sviceus ATCC 29083  Actinomycetota
# 6358   Wolbachia endosymbiont of Trichogramma pretiosum  Pseudomonadota
#
#                     Class
# 0     Gammaproteobacteria
# 1           Actinomycetes
# 2                 Bacilli
# 3     Gammaproteobacteria
# 4                 Bacilli
# ...                   ...
# 6354        Actinomycetes
# 6355              Bacilli
# 6356  Gammaproteobacteria
# 6357        Actinomycetes
# 6358  Alphaproteobacteria
#
# [6359 rows x 5 columns]

# %% [markdown]
# Merge tables and add length of genes column

# %%
eftu = eftu.merge(taxons, left_on='Assemly_accession', right_on='Assembly Accession')
eftu['Length'] = abs(eftu['start'] - eftu['end'])
eftu
# Out:
#    Assemly_accession Refseq_accession    start      end strand        gene_id  \
# 0    GCA_030445085.2       CP124113.1   494670   495851      +    QIA01_02370
# 1    GCF_000005845.2      NC_000913.3   177665   178462      -          b0158
# 2    GCF_000005845.2      NC_000913.3  3470148  3471329      -          b3339
# 3    GCF_000005845.2      NC_000913.3  4175944  4177125      +          b3980
# 4    GCF_000006685.1      NC_002620.2   712354   713535      -     TC_RS03020
# 5    GCF_000006765.1      NC_002516.2  3244345  3246327      +         PA2891
# 6    GCF_000006765.1      NC_002516.2  4767814  4769004      -         PA4265
# 7    GCF_000006765.1      NC_002516.2  4784319  4785509      -         PA4277
# 8    GCF_000006925.2      NC_004337.2   169320   170117      -         SF0150
# 9    GCF_000006925.2      NC_004337.2  3439425  3440606      -         SF3357
# 10   GCF_000006925.2      NC_004337.2  4195696  4196877      +         SF4053
# 11   GCF_000006945.2      NC_003197.2   241273   242070      -        STM0206
# 12   GCF_000006945.2      NC_003197.2  3598312  3599493      -        STM3445
# 13   GCF_000006945.2      NC_003197.2  4360616  4361797      +        STM4146
# 14   GCF_000006985.1      NC_002932.3  2064827  2066005      -  AYT24_RS09945
# 15   GCF_000007025.1      NC_003103.1   934454   935635      -     RC_RS05040
# 16   GCF_000007085.1      NC_003869.1  2176300  2177499      -    TTE_RS10955
# 17   GCF_000007085.1      NC_003869.1  2191779  2192978      -    TTE_RS11025
# 18   GCF_000007125.1      NC_003317.1   768090   769262      +    BME_RS03700
# 19   GCF_000007125.1      NC_003317.1   786042   787214      +    BME_RS03770
#
#    gene_name      protein_id      locus_tag  \
# 0        tuf      WKD00810.1    QIA01_02370
# 1       btuF     NP_414700.1          b0158
# 2       tufA     NP_417798.1          b3339
# 3       tufB     NP_418407.1          b3980
# 4        tuf  WP_010904371.1     TC_RS03020
# 5       atuF     NP_251581.1         PA2891
# 6       tufA     NP_252955.1         PA4265
# 7       tufB     NP_252967.1         PA4277
# 8       yadT     NP_706106.1         SF0150
# 9        tuf     NP_709113.2         SF3357
# 10       tuf     NP_709775.1         SF4053
# 11      btuF     NP_459211.1        STM0206
# 12      tufA     NP_462349.1        STM3445
# 13      tufB     NP_463015.1        STM4146
# 14       tuf  WP_010933844.1  AYT24_RS09945
# 15       tuf  WP_010977589.1     RC_RS05040
# 16       tuf  WP_011026340.1    TTE_RS10955
# 17       tuf  WP_011026354.1    TTE_RS11025
# 18       tuf  WP_002970090.1    BME_RS03700
# 19       tuf  WP_002970090.1    BME_RS03770
#
#                                               product pseudo partial  \
# 0                                elongation factor Tu     --      --
# 1   vitamin B12 ABC transporter periplasmic bindin...     --      --
# 2                  translation elongation factor Tu 1     --      --
# 3                  translation elongation factor Tu 2     --      --
# 4                                elongation factor Tu     --      --
# 5               geranyl-CoA carboxylase subunit alpha     --      --
# 6                                elongation factor Tu     --      --
# 7                                elongation factor Tu     --      --
# 8                vitamin B12-transporter protein BtuF     --      --
# 9                                elongation factor Tu     --      --
# 10                               elongation factor Tu     --      --
# 11     putative cobalamin periplasmic binding protein     --      --
# 12              protein chain elongation factor EF-Tu     --      --
# 13              protein chain elongation factor EF-Tu     --      --
# 14                               elongation factor Tu     --      --
# 15                               elongation factor Tu     --      --
# 16                               elongation factor Tu     --      --
# 17                               elongation factor Tu     --      --
# 18                               elongation factor Tu     --      --
# 19                               elongation factor Tu     --      --
#
#    Assembly Accession  Organism Taxonomic ID  \
# 0     GCA_030445085.2                 478807
# 1     GCF_000005845.2                 511145
# 2     GCF_000005845.2                 511145
# 3     GCF_000005845.2                 511145
# 4     GCF_000006685.1                 243161
# 5     GCF_000006765.1                 208964
# 6     GCF_000006765.1                 208964
# 7     GCF_000006765.1                 208964
# 8     GCF_000006925.2                 198214
# 9     GCF_000006925.2                 198214
# 10    GCF_000006925.2                 198214
# 11    GCF_000006945.2                  99287
# 12    GCF_000006945.2                  99287
# 13    GCF_000006945.2                  99287
# 14    GCF_000006985.1                 194439
# 15    GCF_000007025.1                 272944
# 16    GCF_000007085.1                 273068
# 17    GCF_000007085.1                 273068
# 18    GCF_000007125.1                 224914
# 19    GCF_000007125.1                 224914
#
#                                         Organism Name          Phylum  \
# 0                               Borreliella americana   Spirochaetota
# 1           Escherichia coli str. K-12 substr. MG1655  Pseudomonadota
# 2           Escherichia coli str. K-12 substr. MG1655  Pseudomonadota
# 3           Escherichia coli str. K-12 substr. MG1655  Pseudomonadota
# 4                       Chlamydia muridarum str. Nigg     Chlamydiota
# 5                         Pseudomonas aeruginosa PAO1  Pseudomonadota
# 6                         Pseudomonas aeruginosa PAO1  Pseudomonadota
# 7                         Pseudomonas aeruginosa PAO1  Pseudomonadota
# 8                       Shigella flexneri 2a str. 301  Pseudomonadota
# 9                       Shigella flexneri 2a str. 301  Pseudomonadota
# 10                      Shigella flexneri 2a str. 301  Pseudomonadota
# 11  Salmonella enterica subsp. enterica serovar Ty...  Pseudomonadota
# 12  Salmonella enterica subsp. enterica serovar Ty...  Pseudomonadota
# 13  Salmonella enterica subsp. enterica serovar Ty...  Pseudomonadota
# 14                          Chlorobaculum tepidum TLS     Chlorobiota
# 15                   Rickettsia conorii str. Malish 7  Pseudomonadota
# 16  Caldanaerobacter subterraneus subsp. tengconge...       Bacillota
# 17  Caldanaerobacter subterraneus subsp. tengconge...       Bacillota
# 18                 Brucella melitensis bv. 1 str. 16M  Pseudomonadota
# 19                 Brucella melitensis bv. 1 str. 16M  Pseudomonadota
#
#                   Class  Length
# 0          Spirochaetia    1181
# 1   Gammaproteobacteria     797
# 2   Gammaproteobacteria    1181
# 3   Gammaproteobacteria    1181
# 4            Chlamydiia    1181
# 5   Gammaproteobacteria    1982
# 6   Gammaproteobacteria    1190
# 7   Gammaproteobacteria    1190
# 8   Gammaproteobacteria     797
# 9   Gammaproteobacteria    1181
# 10  Gammaproteobacteria    1181
# 11  Gammaproteobacteria     797
# 12  Gammaproteobacteria    1181
# 13  Gammaproteobacteria    1181
# 14           Chlorobiia    1178
# 15  Alphaproteobacteria    1181
# 16           Clostridia    1199
# 17           Clostridia    1199
# 18  Alphaproteobacteria    1172
# 19  Alphaproteobacteria    1172

# %% [markdown]
# Remove everything that is not tuf gene

# %%
eftu = eftu[~eftu['gene_name'].isin(['btuF', 'atuF', 'yadT', 'spoIIIAH', 'spoIIQ', '--'])]
eftu
# Out:
#    Assemly_accession Refseq_accession    start      end strand        gene_id  \
# 0    GCA_030445085.2       CP124113.1   494670   495851      +    QIA01_02370
# 2    GCF_000005845.2      NC_000913.3  3470148  3471329      -          b3339
# 3    GCF_000005845.2      NC_000913.3  4175944  4177125      +          b3980
# 4    GCF_000006685.1      NC_002620.2   712354   713535      -     TC_RS03020
# 6    GCF_000006765.1      NC_002516.2  4767814  4769004      -         PA4265
# 7    GCF_000006765.1      NC_002516.2  4784319  4785509      -         PA4277
# 9    GCF_000006925.2      NC_004337.2  3439425  3440606      -         SF3357
# 10   GCF_000006925.2      NC_004337.2  4195696  4196877      +         SF4053
# 12   GCF_000006945.2      NC_003197.2  3598312  3599493      -        STM3445
# 13   GCF_000006945.2      NC_003197.2  4360616  4361797      +        STM4146
# 14   GCF_000006985.1      NC_002932.3  2064827  2066005      -  AYT24_RS09945
# 15   GCF_000007025.1      NC_003103.1   934454   935635      -     RC_RS05040
# 16   GCF_000007085.1      NC_003869.1  2176300  2177499      -    TTE_RS10955
# 17   GCF_000007085.1      NC_003869.1  2191779  2192978      -    TTE_RS11025
# 18   GCF_000007125.1      NC_003317.1   768090   769262      +    BME_RS03700
# 19   GCF_000007125.1      NC_003317.1   786042   787214      +    BME_RS03770
#
#    gene_name      protein_id      locus_tag  \
# 0        tuf      WKD00810.1    QIA01_02370
# 2       tufA     NP_417798.1          b3339
# 3       tufB     NP_418407.1          b3980
# 4        tuf  WP_010904371.1     TC_RS03020
# 6       tufA     NP_252955.1         PA4265
# 7       tufB     NP_252967.1         PA4277
# 9        tuf     NP_709113.2         SF3357
# 10       tuf     NP_709775.1         SF4053
# 12      tufA     NP_462349.1        STM3445
# 13      tufB     NP_463015.1        STM4146
# 14       tuf  WP_010933844.1  AYT24_RS09945
# 15       tuf  WP_010977589.1     RC_RS05040
# 16       tuf  WP_011026340.1    TTE_RS10955
# 17       tuf  WP_011026354.1    TTE_RS11025
# 18       tuf  WP_002970090.1    BME_RS03700
# 19       tuf  WP_002970090.1    BME_RS03770
#
#                                   product pseudo partial Assembly Accession  \
# 0                    elongation factor Tu     --      --    GCA_030445085.2
# 2      translation elongation factor Tu 1     --      --    GCF_000005845.2
# 3      translation elongation factor Tu 2     --      --    GCF_000005845.2
# 4                    elongation factor Tu     --      --    GCF_000006685.1
# 6                    elongation factor Tu     --      --    GCF_000006765.1
# 7                    elongation factor Tu     --      --    GCF_000006765.1
# 9                    elongation factor Tu     --      --    GCF_000006925.2
# 10                   elongation factor Tu     --      --    GCF_000006925.2
# 12  protein chain elongation factor EF-Tu     --      --    GCF_000006945.2
# 13  protein chain elongation factor EF-Tu     --      --    GCF_000006945.2
# 14                   elongation factor Tu     --      --    GCF_000006985.1
# 15                   elongation factor Tu     --      --    GCF_000007025.1
# 16                   elongation factor Tu     --      --    GCF_000007085.1
# 17                   elongation factor Tu     --      --    GCF_000007085.1
# 18                   elongation factor Tu     --      --    GCF_000007125.1
# 19                   elongation factor Tu     --      --    GCF_000007125.1
#
#     Organism Taxonomic ID                                      Organism Name  \
# 0                  478807                              Borreliella americana
# 2                  511145          Escherichia coli str. K-12 substr. MG1655
# 3                  511145          Escherichia coli str. K-12 substr. MG1655
# 4                  243161                      Chlamydia muridarum str. Nigg
# 6                  208964                        Pseudomonas aeruginosa PAO1
# 7                  208964                        Pseudomonas aeruginosa PAO1
# 9                  198214                      Shigella flexneri 2a str. 301
# 10                 198214                      Shigella flexneri 2a str. 301
# 12                  99287  Salmonella enterica subsp. enterica serovar Ty...
# 13                  99287  Salmonella enterica subsp. enterica serovar Ty...
# 14                 194439                          Chlorobaculum tepidum TLS
# 15                 272944                   Rickettsia conorii str. Malish 7
# 16                 273068  Caldanaerobacter subterraneus subsp. tengconge...
# 17                 273068  Caldanaerobacter subterraneus subsp. tengconge...
# 18                 224914                 Brucella melitensis bv. 1 str. 16M
# 19                 224914                 Brucella melitensis bv. 1 str. 16M
#
#             Phylum                Class  Length
# 0    Spirochaetota         Spirochaetia    1181
# 2   Pseudomonadota  Gammaproteobacteria    1181
# 3   Pseudomonadota  Gammaproteobacteria    1181
# 4      Chlamydiota           Chlamydiia    1181
# 6   Pseudomonadota  Gammaproteobacteria    1190
# 7   Pseudomonadota  Gammaproteobacteria    1190
# 9   Pseudomonadota  Gammaproteobacteria    1181
# 10  Pseudomonadota  Gammaproteobacteria    1181
# 12  Pseudomonadota  Gammaproteobacteria    1181
# 13  Pseudomonadota  Gammaproteobacteria    1181
# 14     Chlorobiota           Chlorobiia    1178
# 15  Pseudomonadota  Alphaproteobacteria    1181
# 16       Bacillota           Clostridia    1199
# 17       Bacillota           Clostridia    1199
# 18  Pseudomonadota  Alphaproteobacteria    1172
# 19  Pseudomonadota  Alphaproteobacteria    1172

# %% [markdown]
# Remove pesudo genes, partial genes, and genes shorter than 1000bp

# %%
genomes_with_true_pseudo = eftu[eftu['pseudo'] == 'TRUE'].iloc[:, 0].unique()
eftu = eftu[~eftu.iloc[:, 0].isin(genomes_with_true_pseudo)]
print(len(set(eftu['Assemly_accession'])))

genomes_with_true_partial = eftu[eftu['partial'] == 'TRUE'].iloc[:, 0].unique()
eftu = eftu[~eftu.iloc[:, 0].isin(genomes_with_true_partial)]
print(len(set(eftu['Assemly_accession'])))

genomes_short_eftu = eftu[eftu['Length'] < 1000].iloc[:, 0].unique()
eftu = eftu[~eftu.iloc[:, 0].isin(genomes_short_eftu)]

print(len(set(eftu['Assemly_accession'])))
eftu
# Out:
# 10
# 10
# 10
#    Assemly_accession Refseq_accession    start      end strand        gene_id  \
# 0    GCA_030445085.2       CP124113.1   494670   495851      +    QIA01_02370
# 2    GCF_000005845.2      NC_000913.3  3470148  3471329      -          b3339
# 3    GCF_000005845.2      NC_000913.3  4175944  4177125      +          b3980
# 4    GCF_000006685.1      NC_002620.2   712354   713535      -     TC_RS03020
# 6    GCF_000006765.1      NC_002516.2  4767814  4769004      -         PA4265
# 7    GCF_000006765.1      NC_002516.2  4784319  4785509      -         PA4277
# 9    GCF_000006925.2      NC_004337.2  3439425  3440606      -         SF3357
# 10   GCF_000006925.2      NC_004337.2  4195696  4196877      +         SF4053
# 12   GCF_000006945.2      NC_003197.2  3598312  3599493      -        STM3445
# 13   GCF_000006945.2      NC_003197.2  4360616  4361797      +        STM4146
# 14   GCF_000006985.1      NC_002932.3  2064827  2066005      -  AYT24_RS09945
# 15   GCF_000007025.1      NC_003103.1   934454   935635      -     RC_RS05040
# 16   GCF_000007085.1      NC_003869.1  2176300  2177499      -    TTE_RS10955
# 17   GCF_000007085.1      NC_003869.1  2191779  2192978      -    TTE_RS11025
# 18   GCF_000007125.1      NC_003317.1   768090   769262      +    BME_RS03700
# 19   GCF_000007125.1      NC_003317.1   786042   787214      +    BME_RS03770
#
#    gene_name      protein_id      locus_tag  \
# 0        tuf      WKD00810.1    QIA01_02370
# 2       tufA     NP_417798.1          b3339
# 3       tufB     NP_418407.1          b3980
# 4        tuf  WP_010904371.1     TC_RS03020
# 6       tufA     NP_252955.1         PA4265
# 7       tufB     NP_252967.1         PA4277
# 9        tuf     NP_709113.2         SF3357
# 10       tuf     NP_709775.1         SF4053
# 12      tufA     NP_462349.1        STM3445
# 13      tufB     NP_463015.1        STM4146
# 14       tuf  WP_010933844.1  AYT24_RS09945
# 15       tuf  WP_010977589.1     RC_RS05040
# 16       tuf  WP_011026340.1    TTE_RS10955
# 17       tuf  WP_011026354.1    TTE_RS11025
# 18       tuf  WP_002970090.1    BME_RS03700
# 19       tuf  WP_002970090.1    BME_RS03770
#
#                                   product pseudo partial Assembly Accession  \
# 0                    elongation factor Tu     --      --    GCA_030445085.2
# 2      translation elongation factor Tu 1     --      --    GCF_000005845.2
# 3      translation elongation factor Tu 2     --      --    GCF_000005845.2
# 4                    elongation factor Tu     --      --    GCF_000006685.1
# 6                    elongation factor Tu     --      --    GCF_000006765.1
# 7                    elongation factor Tu     --      --    GCF_000006765.1
# 9                    elongation factor Tu     --      --    GCF_000006925.2
# 10                   elongation factor Tu     --      --    GCF_000006925.2
# 12  protein chain elongation factor EF-Tu     --      --    GCF_000006945.2
# 13  protein chain elongation factor EF-Tu     --      --    GCF_000006945.2
# 14                   elongation factor Tu     --      --    GCF_000006985.1
# 15                   elongation factor Tu     --      --    GCF_000007025.1
# 16                   elongation factor Tu     --      --    GCF_000007085.1
# 17                   elongation factor Tu     --      --    GCF_000007085.1
# 18                   elongation factor Tu     --      --    GCF_000007125.1
# 19                   elongation factor Tu     --      --    GCF_000007125.1
#
#     Organism Taxonomic ID                                      Organism Name  \
# 0                  478807                              Borreliella americana
# 2                  511145          Escherichia coli str. K-12 substr. MG1655
# 3                  511145          Escherichia coli str. K-12 substr. MG1655
# 4                  243161                      Chlamydia muridarum str. Nigg
# 6                  208964                        Pseudomonas aeruginosa PAO1
# 7                  208964                        Pseudomonas aeruginosa PAO1
# 9                  198214                      Shigella flexneri 2a str. 301
# 10                 198214                      Shigella flexneri 2a str. 301
# 12                  99287  Salmonella enterica subsp. enterica serovar Ty...
# 13                  99287  Salmonella enterica subsp. enterica serovar Ty...
# 14                 194439                          Chlorobaculum tepidum TLS
# 15                 272944                   Rickettsia conorii str. Malish 7
# 16                 273068  Caldanaerobacter subterraneus subsp. tengconge...
# 17                 273068  Caldanaerobacter subterraneus subsp. tengconge...
# 18                 224914                 Brucella melitensis bv. 1 str. 16M
# 19                 224914                 Brucella melitensis bv. 1 str. 16M
#
#             Phylum                Class  Length
# 0    Spirochaetota         Spirochaetia    1181
# 2   Pseudomonadota  Gammaproteobacteria    1181
# 3   Pseudomonadota  Gammaproteobacteria    1181
# 4      Chlamydiota           Chlamydiia    1181
# 6   Pseudomonadota  Gammaproteobacteria    1190
# 7   Pseudomonadota  Gammaproteobacteria    1190
# 9   Pseudomonadota  Gammaproteobacteria    1181
# 10  Pseudomonadota  Gammaproteobacteria    1181
# 12  Pseudomonadota  Gammaproteobacteria    1181
# 13  Pseudomonadota  Gammaproteobacteria    1181
# 14     Chlorobiota           Chlorobiia    1178
# 15  Pseudomonadota  Alphaproteobacteria    1181
# 16       Bacillota           Clostridia    1199
# 17       Bacillota           Clostridia    1199
# 18  Pseudomonadota  Alphaproteobacteria    1172
# 19  Pseudomonadota  Alphaproteobacteria    1172

# %%
eftu.to_csv("eftu_w_phylum.tsv", sep='\t', index=False, decimal=',')

# %% [markdown]
# Create summary for organisms with clear Phylum and Class assigned

# %%
summary = (
    eftu.groupby(["Organism Name", "Phylum", "Class", 'Refseq_accession', 'Assemly_accession'])
    .size()
    .reset_index(name="tuf_count")
    .sort_values("tuf_count", ascending=False)
)
summary
# Out:
#                                        Organism Name          Phylum  \
# 1                 Brucella melitensis bv. 1 str. 16M  Pseudomonadota
# 2  Caldanaerobacter subterraneus subsp. tengconge...       Bacillota
# 9                      Shigella flexneri 2a str. 301  Pseudomonadota
# 5          Escherichia coli str. K-12 substr. MG1655  Pseudomonadota
# 8  Salmonella enterica subsp. enterica serovar Ty...  Pseudomonadota
# 6                        Pseudomonas aeruginosa PAO1  Pseudomonadota
# 0                              Borreliella americana   Spirochaetota
# 3                      Chlamydia muridarum str. Nigg     Chlamydiota
# 4                          Chlorobaculum tepidum TLS     Chlorobiota
# 7                   Rickettsia conorii str. Malish 7  Pseudomonadota
#
#                  Class Refseq_accession Assemly_accession  tuf_count
# 1  Alphaproteobacteria      NC_003317.1   GCF_000007125.1          2
# 2           Clostridia      NC_003869.1   GCF_000007085.1          2
# 9  Gammaproteobacteria      NC_004337.2   GCF_000006925.2          2
# 5  Gammaproteobacteria      NC_000913.3   GCF_000005845.2          2
# 8  Gammaproteobacteria      NC_003197.2   GCF_000006945.2          2
# 6  Gammaproteobacteria      NC_002516.2   GCF_000006765.1          2
# 0         Spirochaetia       CP124113.1   GCA_030445085.2          1
# 3           Chlamydiia      NC_002620.2   GCF_000006685.1          1
# 4           Chlorobiia      NC_002932.3   GCF_000006985.1          1
# 7  Alphaproteobacteria      NC_003103.1   GCF_000007025.1          1

# %%
summary.to_csv('tuf_summary.tsv', sep='\t', index=False, decimal=',')
